# %%
import json

with open(r"D:\Self_Learning\RAG_using_ATLAS\RAG_Concept_Learning\mongodb-atlas-rag\data\processed\embedded_chunks.json", "r", encoding="utf-8") as f:
    data = json.load(f)

print(type(data))
print(len(data))
print(data[0].keys())

print(data[0]["chunk_id"])
print(data[0]["parent_id"])

print(type(data[0]["embedding"]))
print(len(data[0]["embedding"]))
# Out:
# <class 'list'>
# 112
# dict_keys(['chunk_id', 'parent_id', 'chunk_text', 'metadata', 'embedding'])
# chunk_0
# parent_0
# <class 'list'>
# 1024
